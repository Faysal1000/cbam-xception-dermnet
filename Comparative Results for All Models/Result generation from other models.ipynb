# %%
models_data = {
    "ConvNeXtBase": {
        "train": {"accuracy": 0.928, "precision": 0.9363, "recall": 0.928, "f1_score": 0.9287},
        "validation": {"accuracy": 0.8598, "precision": 0.8719, "recall": 0.8598, "f1_score": 0.8613},
        "test": {"accuracy": 0.8588, "precision": 0.8621, "recall": 0.8588, "f1_score": 0.8591}
    },
    "ConvNeXtLarge": {
        "train": {"accuracy": 0.9301, "precision": 0.9362, "recall": 0.9301, "f1_score": 0.9297},
        "validation": {"accuracy": 0.863, "precision": 0.8728, "recall": 0.863, "f1_score": 0.8648},
        "test": {"accuracy": 0.8596, "precision": 0.8626, "recall": 0.8596, "f1_score": 0.8607}
    },
    "ConvNeXtSmall": {
        "train": {"accuracy": 0.8789, "precision": 0.8997, "recall": 0.8789, "f1_score": 0.8794},
        "validation": {"accuracy": 0.7938, "precision": 0.8098, "recall": 0.7938, "f1_score": 0.7958},
        "test": {"accuracy": 0.7963, "precision": 0.7992, "recall": 0.7963, "f1_score": 0.7951}
    },
    "ConvNeXtTiny": {
        "train": {"accuracy": 0.8937, "precision": 0.911, "recall": 0.8937, "f1_score": 0.8943},
        "validation": {"accuracy": 0.8401, "precision": 0.8571, "recall": 0.8401, "f1_score": 0.8418},
        "test": {"accuracy": 0.8343, "precision": 0.8360, "recall": 0.8343, "f1_score": 0.8333}
    },
    "ConvNeXtXLarge": {
        "train": {"accuracy": 0.9325, "precision": 0.9394, "recall": 0.9325, "f1_score": 0.9327},
        "validation": {"accuracy": 0.8808, "precision": 0.8907, "recall": 0.8808, "f1_score": 0.8822},
        "test": {"accuracy": 0.8749, "precision": 0.8780, "recall": 0.8749, "f1_score": 0.8756}
    },
    "DenseNet121": {
        "train": {"accuracy": 0.8452, "precision": 0.8735, "recall": 0.8452, "f1_score": 0.8437},
        "validation": {"accuracy": 0.8281, "precision": 0.8569, "recall": 0.8281, "f1_score": 0.8258},
        "test": {"accuracy": 0.8170, "precision": 0.8186, "recall": 0.8170, "f1_score": 0.8162}
    },
    "DenseNet169": {
        "train": {"accuracy": 0.8537, "precision": 0.8795, "recall": 0.8537, "f1_score": 0.8534},
        "validation": {"accuracy": 0.8297, "precision": 0.8574, "recall": 0.8297, "f1_score": 0.8309},
        "test": {"accuracy": 0.8249, "precision": 0.8217, "recall": 0.8249, "f1_score": 0.8218}
    },
    "DenseNet201": {
        "train": {"accuracy": 0.8682, "precision": 0.8895, "recall": 0.8682, "f1_score": 0.8672},
        "validation": {"accuracy": 0.8413, "precision": 0.8685, "recall": 0.8413, "f1_score": 0.8426},
        "test": {"accuracy": 0.8296, "precision": 0.8324, "recall": 0.8296, "f1_score": 0.8291}
    },
    "EfficientNetB0": {
        "train": {"accuracy": 0.8716, "precision": 0.8959, "recall": 0.8716, "f1_score": 0.8723},
        "validation": {"accuracy": 0.8602, "precision": 0.885, "recall": 0.8602, "f1_score": 0.8632},
        "test": {"accuracy": 0.8526, "precision": 0.8548, "recall": 0.8526, "f1_score": 0.8524}
    },
    "EfficientNetB1": {
        "train": {"accuracy": 0.8389, "precision": 0.8654, "recall": 0.8389, "f1_score": 0.8389},
        "validation": {"accuracy": 0.83, "precision": 0.8646, "recall": 0.83, "f1_score": 0.8289},
        "test": {"accuracy": 0.8262, "precision": 0.8269, "recall": 0.8262, "f1_score": 0.8231}
    },
    "EfficientNetB2": {
        "train": {"accuracy": 0.8615, "precision": 0.8757, "recall": 0.8615, "f1_score": 0.8601},
        "validation": {"accuracy": 0.8541, "precision": 0.8904, "recall": 0.8541, "f1_score": 0.8551},
        "test": {"accuracy": 0.8549, "precision": 0.8595, "recall": 0.8549, "f1_score": 0.8544}
    },
    "EfficientNetB3": {
        "train": {"accuracy": 0.833, "precision": 0.8669, "recall": 0.833, "f1_score": 0.8324},
        "validation": {"accuracy": 0.8311, "precision": 0.8678, "recall": 0.8311, "f1_score": 0.8314},
        "test": {"accuracy": 0.8283, "precision": 0.8356, "recall": 0.8283, "f1_score": 0.8265}
    },
    "EfficientNetB4": {
        "train": {"accuracy": 0.8287, "precision": 0.8667, "recall": 0.8287, "f1_score": 0.8275},
        "validation": {"accuracy": 0.8293, "precision": 0.8629, "recall": 0.8293, "f1_score": 0.8308},
        "test": {"accuracy": 0.8234, "precision": 0.8246, "recall": 0.8234, "f1_score": 0.8225}
    },
    "EfficientNetB5": {
        "train": {"accuracy": 0.8404, "precision": 0.8589, "recall": 0.8404, "f1_score": 0.841},
        "validation": {"accuracy": 0.8113, "precision": 0.8486, "recall": 0.8113, "f1_score": 0.813},
        "test": {"accuracy": 0.8115, "precision": 0.8164, "recall": 0.8115, "f1_score": 0.8088}
    },
    "EfficientNetB6": {
        "train": {"accuracy": 0.8185, "precision": 0.86, "recall": 0.8185, "f1_score": 0.818},
        "validation": {"accuracy": 0.803, "precision": 0.8435, "recall": 0.803, "f1_score": 0.8011},
        "test": {"accuracy": 0.8044, "precision": 0.8027, "recall": 0.8044, "f1_score": 0.8015}
    },
    "EfficientNetB7": {
        "train": {"accuracy": 0.8292, "precision": 0.8672, "recall": 0.8292, "f1_score": 0.8311},
        "validation": {"accuracy": 0.8253, "precision": 0.8622, "recall": 0.8253, "f1_score": 0.8221},
        "test": {"accuracy": 0.8153, "precision": 0.8177, "recall": 0.8153, "f1_score": 0.8163}
    },
    "EfficientNetV2B0": {
        "train": {"accuracy": 0.8669, "precision": 0.8915, "recall": 0.8669, "f1_score": 0.8672},
        "validation": {"accuracy": 0.8517, "precision": 0.8757, "recall": 0.8517, "f1_score": 0.8509},
        "test": {"accuracy": 0.8394, "precision": 0.8385, "recall": 0.8394, "f1_score": 0.8379}
    },
    "EfficientNetV2B1": {
        "train": {"accuracy": 0.8513, "precision": 0.8785, "recall": 0.8513, "f1_score": 0.8489},
        "validation": {"accuracy": 0.8417, "precision": 0.8727, "recall": 0.8417, "f1_score": 0.8422},
        "test": {"accuracy": 0.8449, "precision": 0.8435, "recall": 0.8449, "f1_score": 0.8423}
    },
    "EfficientNetV2B2": {
        "train": {"accuracy": 0.8485, "precision": 0.8775, "recall": 0.8485, "f1_score": 0.8475},
        "validation": {"accuracy": 0.8591, "precision": 0.8834, "recall": 0.8591, "f1_score": 0.858},
        "test": {"accuracy": 0.8513, "precision": 0.8503, "recall": 0.8513, "f1_score": 0.8499}
    },
    "EfficientNetV2B3": {
        "train": {"accuracy": 0.8367, "precision": 0.8737, "recall": 0.8367, "f1_score": 0.8365},
        "validation": {"accuracy": 0.8483, "precision": 0.8787, "recall": 0.8483, "f1_score": 0.8454},
        "test": {"accuracy": 0.8406, "precision": 0.8399, "recall": 0.8406, "f1_score": 0.8400}
    },
    "EfficientNetV2L": {
        "train": {"accuracy": 0.7996, "precision": 0.8469, "recall": 0.7996, "f1_score": 0.7981},
        "validation": {"accuracy": 0.7909, "precision": 0.8343, "recall": 0.7909, "f1_score": 0.7897},
        "test": {"accuracy": 0.7846, "precision": 0.7868, "recall": 0.7846, "f1_score": 0.7816}
    },
    "EfficientNetV2M": {
        "train": {"accuracy": 0.7821, "precision": 0.8373, "recall": 0.7821, "f1_score": 0.7778},
        "validation": {"accuracy": 0.7743, "precision": 0.8246, "recall": 0.7743, "f1_score": 0.7713},
        "test": {"accuracy": 0.7725, "precision": 0.7692, "recall": 0.7725, "f1_score": 0.7689}
    },
    "EfficientNetV2S": {
        "train": {"accuracy": 0.8273, "precision": 0.8663, "recall": 0.8273, "f1_score": 0.8274},
        "validation": {"accuracy": 0.8235, "precision": 0.8629, "recall": 0.8235, "f1_score": 0.822},
        "test": {"accuracy": 0.8183, "precision": 0.8198, "recall": 0.8183, "f1_score": 0.8138}
    },
    "InceptionResNetV2": {
        "train": {"accuracy": 0.7655, "precision": 0.8233, "recall": 0.7048, "f1_score": 0.7594},
        "validation": {"accuracy": 0.7844, "precision": 0.8375, "recall": 0.7232, "f1_score": 0.7762},
        "test": {"accuracy": 0.7804, "precision": 0.7827, "recall": 0.7804, "f1_score": 0.7800}
    },
    "InceptionV3": {
        "train": {"accuracy": 0.737, "precision": 0.8081, "recall": 0.737, "f1_score": 0.7291},
        "validation": {"accuracy": 0.7484, "precision": 0.8255, "recall": 0.7484, "f1_score": 0.7409},
        "test": {"accuracy": 0.7501, "precision": 0.7524, "recall": 0.7501, "f1_score": 0.7496}
    },
    "MobileNet": {
        "train": {"accuracy": 0.5684, "precision": 0.7506, "recall": 0.5684, "f1_score": 0.5157},
        "validation": {"accuracy": 0.5907, "precision": 0.7694, "recall": 0.5907, "f1_score": 0.5415},
        "test": {"accuracy": 0.5952, "precision": 0.5922, "recall": 0.5952, "f1_score": 0.5889}
    },
    "MobileNetV2": {
        "train": {"accuracy": 0.4591, "precision": 0.6646, "recall": 0.4591, "f1_score": 0.3396},
        "validation": {"accuracy": 0.4744, "precision": 0.7583, "recall": 0.4744, "f1_score": 0.3699},
        "test": {"accuracy": 0.4680, "precision": 0.4779, "recall": 0.4680, "f1_score": 0.4604}
    },
    "MobileNetV3Large": {
        "train": {"accuracy": 0.9088, "precision": 0.9208, "recall": 0.9088, "f1_score": 0.9092},
        "validation": {"accuracy": 0.8739, "precision": 0.8922, "recall": 0.8739, "f1_score": 0.8754},
        "test": {"accuracy": 0.8805, "precision": 0.8797, "recall": 0.8805, "f1_score": 0.8792}
    },
    "MobileNetV3Small": {
        "train": {"accuracy": 0.8793, "precision": 0.8939, "recall": 0.8793, "f1_score": 0.8799},
        "validation": {"accuracy": 0.8336, "precision": 0.8597, "recall": 0.8336, "f1_score": 0.8355},
        "test": {"accuracy": 0.8328, "precision": 0.8353, "recall": 0.8328, "f1_score": 0.8330}
    },
    "NASNetLarge": {
        "train": {"accuracy": 0.7717, "precision": 0.8169, "recall": 0.7717, "f1_score": 0.7671},
        "validation": {"accuracy": 0.7460, "precision": 0.8155, "recall": 0.7460, "f1_score": 0.7420},
        "test": {"accuracy": 0.7524, "precision": 0.7502, "recall": 0.7524, "f1_score": 0.7484}
    },
    "NASNetMobile": {
        "train": {"accuracy": 0.7278, "precision": 0.7803, "recall": 0.7278, "f1_score": 0.7112},
        "validation": {"accuracy": 0.6703, "precision": 0.7638, "recall": 0.6703, "f1_score": 0.6613},
        "test": {"accuracy": 0.6709, "precision": 0.6662, "recall": 0.6709, "f1_score": 0.6619}
    },
    "ResNet101": {
        "train": {"accuracy": 0.3924, "precision": 0.5894, "recall": 0.3924, "f1_score": 0.1975},
        "validation": {"accuracy": 0.4120, "precision": 0.6663, "recall": 0.4120, "f1_score": 0.2874},
        "test": {"accuracy": 0.4063, "precision": 0.4027, "recall": 0.4063, "f1_score": 0.3715}
    },
    "ResNet101V2": {
        "train": {"accuracy": 0.8562, "precision": 0.8821, "recall": 0.8562, "f1_score": 0.8590},
        "validation": {"accuracy": 0.8596, "precision": 0.8818, "recall": 0.8596, "f1_score": 0.8596},
        "test": {"accuracy": 0.8590, "precision": 0.8581, "recall": 0.8590, "f1_score": 0.8578}
    },
    "ResNet152": {
        "train": {"accuracy": 0.3780, "precision": 0.6190, "recall": 0.3780, "f1_score": 0.1769},
        "validation": {"accuracy": 0.4020, "precision": 0.6992, "recall": 0.4020, "f1_score": 0.2559},
        "test": {"accuracy": 0.4073, "precision": 0.4402, "recall": 0.4073, "f1_score": 0.3861}
    },
    "ResNet152V2": {
        "train": {"accuracy": 0.8532, "precision": 0.8802, "recall": 0.8532, "f1_score": 0.8531},
        "validation": {"accuracy": 0.8484, "precision": 0.8788, "recall": 0.8484, "f1_score": 0.8516},
        "test": {"accuracy": 0.8500, "precision": 0.8491, "recall": 0.8500, "f1_score": 0.8481}
    },
    "ResNet50": {
        "train": {"accuracy": 0.3907, "precision": 0.6493, "recall": 0.3907, "f1_score": 0.2246},
        "validation": {"accuracy": 0.4068, "precision": 0.7098, "recall": 0.4068, "f1_score": 0.3133},
        "test": {"accuracy": 0.4082, "precision": 0.4377, "recall": 0.4082, "f1_score": 0.3801}
    },
    "ResNet50V2": {
        "train": {"accuracy": 0.8686, "precision": 0.8916, "recall": 0.8686, "f1_score": 0.8685},
        "validation": {"accuracy": 0.8667, "precision": 0.8895, "recall": 0.8667, "f1_score": 0.8668},
        "test": {"accuracy": 0.8741, "precision": 0.8743, "recall": 0.8741, "f1_score": 0.8738}
    },
    "VGG16": {
        "train": {"accuracy": 0.8523, "precision": 0.8827, "recall": 0.8523, "f1_score": 0.8532},
        "validation": {"accuracy": 0.8244, "precision": 0.8498, "recall": 0.8244, "f1_score": 0.8250},
        "test": {"accuracy": 0.8308, "precision": 0.8317, "recall": 0.8308, "f1_score": 0.8295}
    },
    "VGG19": {
        "train": {"accuracy": 0.8369, "precision": 0.8720, "recall": 0.8369, "f1_score": 0.8359},
        "validation": {"accuracy": 0.8065, "precision": 0.8394, "recall": 0.8065, "f1_score": 0.8040},
        "test": {"accuracy": 0.8081, "precision": 0.8120, "recall": 0.8081, "f1_score": 0.8085}
    }
}

# %%
# Add per-model metadata for parameter count and training time (minutes)
model_metadata = {
    "ConvNeXtBase":    {"param_count": 104_000_000, "train_time_min": 190},
    "ConvNeXtLarge":   {"param_count": 212_000_000, "train_time_min": 220},
    "ConvNeXtSmall":   {"param_count": 29_000_000,  "train_time_min": 178},
    "ConvNeXtTiny":    {"param_count": 5_000_000,   "train_time_min": 170},
    "ConvNeXtXLarge":  {"param_count": 330_000_000, "train_time_min": 280},
    "DenseNet121":     {"param_count": 8_000_000,   "train_time_min": 120},
    "DenseNet169":     {"param_count": 14_000_000,  "train_time_min": 133},
    "DenseNet201":     {"param_count": 20_000_000,  "train_time_min": 150},
    "EfficientNetB0":  {"param_count": 5_300_000,  "train_time_min": 83},
    "EfficientNetB1":  {"param_count": 7_800_000,  "train_time_min": 90},
    "EfficientNetB2":  {"param_count": 9_200_000,  "train_time_min": 91},
    "EfficientNetB3":  {"param_count": 12_000_000, "train_time_min": 110},
    "EfficientNetB4":  {"param_count": 19_000_000, "train_time_min": 108},
    "EfficientNetB5":  {"param_count": 30_000_000, "train_time_min": 135},
    "EfficientNetB6":  {"param_count": 43_000_000, "train_time_min": 153},
    "EfficientNetB7":  {"param_count": 66_000_000, "train_time_min": 201},
    "EfficientNetV2B0": {"param_count": 7_100_000,  "train_time_min": 80},
    "EfficientNetV2B1": {"param_count": 8_300_000,  "train_time_min": 87},
    "EfficientNetV2B2": {"param_count": 9_200_000,  "train_time_min": 93},
    "EfficientNetV2B3": {"param_count": 12_100_000, "train_time_min": 97},
    "EfficientNetV2L": {"param_count": 121_000_000, "train_time_min": 218},
    "EfficientNetV2M": {"param_count": 54_000_000,  "train_time_min": 125},
    "EfficientNetV2S": {"param_count": 21_000_000,  "train_time_min": 110},
    "InceptionResNetV2": {"param_count": 55_000_000, "train_time_min": 135},
    "InceptionV3": {"param_count": 24_000_000, "train_time_min": 95},
    "MobileNet": {"param_count": 4_200_000, "train_time_min": 80},
    "MobileNetV2": {"param_count": 3_500_000, "train_time_min": 85},
    "MobileNetV3Large": {"param_count": 5_400_000, "train_time_min": 85},
    "MobileNetV3Small": {"param_count": 2_900_000, "train_time_min": 76},
    "NASNetLarge": {"param_count": 88_000_000, "train_time_min": 205},
    "NASNetMobile": {"param_count": 5_300_000, "train_time_min": 90},
    "ResNet101": {"param_count": 44_000_000, "train_time_min": 105},
    "ResNet101V2": {"param_count": 44_000_000, "train_time_min": 104},
    "ResNet152": {"param_count": 60_000_000, "train_time_min": 146},
    "ResNet152V2": {"param_count": 60_000_000, "train_time_min": 135},
    "ResNet50": {"param_count": 25_000_000, "train_time_min": 92},
    "ResNet50V2": {"param_count": 25_000_000, "train_time_min": 93},
    "VGG16": {"param_count": 138_000_000, "train_time_min": 104},
    "VGG19": {"param_count": 143_000_000, "train_time_min": 110},
}

for model, meta in model_metadata.items():
    if model in models_data:
        models_data[model]["param_count"] = meta["param_count"]
        models_data[model]["train_time_min"] = meta["train_time_min"]

print("Added param_count and train_time_min for models in models_data.")
# Out:
# Added param_count and train_time_min for models in models_data.

# %%
import matplotlib.pyplot as plt

models = list(models_data.keys())
test_accuracies = [models_data[m]["test"]["accuracy"] for m in models]

plt.figure(figsize=(9, 4))
bars = plt.bar(models, test_accuracies, width=0.3, color='skyblue', edgecolor='black')

for bar, acc in zip(bars, test_accuracies):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.005, f"{acc:.3f}",
             ha='center', va='bottom', fontsize=9, rotation=90, fontweight='bold')

plt.xticks(rotation=90, fontsize=9)
plt.ylabel("Test Accuracy", fontsize=12)
#plt.title("Test Accuracy Comparison Across Models", fontsize=13, fontweight='normal')

# 🔹 Remove top and right bounding box
for spine in ['top', 'right']:
    plt.gca().spines[spine].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# Accuracy vs parameter count tradeoff plot
import matplotlib.pyplot as plt

model_names = []
param_counts = []
accuracies = []

for m, info in models_data.items():
    if "param_count" in info and "test" in info:
        model_names.append(m)
        param_counts.append(info["param_count"] / 1e6)  # millions
        accuracies.append(info["test"]["accuracy"])

plt.figure(figsize=(10, 5))
plt.scatter(param_counts, accuracies, s=80, c='tab:blue', alpha=0.75, edgecolor='k')
for name, x, y in zip(model_names, param_counts, accuracies):
    plt.text(x, y + 0.003, name, fontsize=8, rotation=15, va='bottom')

plt.xlabel('Parameter Count (Millions)', fontsize=12)
plt.ylabel('Test Accuracy', fontsize=12)
plt.title('Accuracy vs Parameter Count Tradeoff', fontsize=14, fontweight='bold')
plt.grid(alpha=0.25)
plt.ylim(min(accuracies) - 0.02, max(accuracies) + 0.02)
plt.tight_layout()
plt.show()

# %%
# Parameter Count vs Training Time plot
model_names_time = []
param_counts_time = []
train_times = []

for m, info in models_data.items():
    if "param_count" in info and "train_time_min" in info:
        model_names_time.append(m)
        param_counts_time.append(info["param_count"] / 1e6)  # millions
        train_times.append(info["train_time_min"])

plt.figure(figsize=(10, 5))
plt.scatter(param_counts_time, train_times, s=90, c='tab:green', alpha=0.75, edgecolor='k')
for name, x, y in zip(model_names_time, param_counts_time, train_times):
    plt.text(x, y + 2, name, fontsize=7, rotation=15, va='bottom')

plt.xlabel('Parameter Count (Millions)', fontsize=12)
plt.ylabel('Training Time (Minutes)', fontsize=12)
plt.title('Parameter Count vs Training Time', fontsize=14, fontweight='bold')
plt.grid(alpha=0.2)
plt.tight_layout()
plt.show()

# %%
# Import required libraries
import matplotlib.pyplot as plt  # For plotting
import numpy as np               # For numerical operations

# Define the metrics and phases (used throughout the radar plots)
metrics = ["accuracy", "precision", "recall", "f1_score"]  # Common performance metrics
phases = ["train", "test"]  # Data phases
best_model_names = [] # for storing best test accuracy model from every category of the model

# %%
# Define a function to generate radar charts for filtered models and selected data phase
def plot_radar_filtered(models_data, 
                        phase,                     # Phase of the dataset: 'train', 'validation', or 'test'
                        filter_keyword=None,       # Keyword(s) to filter model names (can be a string or list of strings)
                        set_ylim=[0.6, 1.0],       # Y-axis limits for radar chart
                        set_yticks=[0.6, 0.7, 0.8, 0.9, 1.0],  # Y-axis tick marks
                        fig_size=(5, 5)):          # Size of the radar chart figure

    # Set the metric labels for radar chart axes
    labels = metrics
    num_vars = len(labels)  # Number of axes = number of metrics

    # Compute angle for each axis in the radar chart
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
    angles += [angles[0]]  # Repeat the first angle at the end to complete the circular plot

    # Create a polar plot for the radar chart
    fig, ax = plt.subplots(figsize=fig_size, subplot_kw=dict(polar=True))

    # === Filter models by keywords ===
    if filter_keyword:
        # If the user passed a single keyword (string), convert it to a list for uniform processing
        if isinstance(filter_keyword, str):
            filter_keyword = [filter_keyword]
        
        # Filter the models whose names contain ANY of the keywords (case-insensitive match)
        filtered_models = {
            k: v for k, v in models_data.items()
            if any(keyword.lower() in k.lower() for keyword in filter_keyword)
        }
    else:
        # If no filter keywords provided, include all models
        filtered_models = models_data

    # If no models match the filter, print a warning and return None
    if not filtered_models:
        print(f"No models found with keywords: {filter_keyword}")
        return None

    # Variables to keep track of the model with the highest accuracy
    best_model = None
    best_accuracy = -1

    # === Plot radar for each filtered model ===
    for model_name, model_info in filtered_models.items():
        # Extract values for each metric in the selected phase (e.g., 'test')
        values = [model_info[phase][metric] for metric in labels]
        values += [values[0]]  # Repeat the first value to close the polygon

        # Draw the polygon line for the model
        ax.plot(angles, values, label=model_name)

        # Optionally fill the radar area under the curve with transparency
        ax.fill(angles, values, alpha=0.05)

        # Update best model if this one has a higher accuracy
        current_accuracy = model_info[phase]["accuracy"]
        if current_accuracy > best_accuracy:
            best_accuracy = current_accuracy
            best_model = model_name

    # === Radar chart formatting and aesthetics ===
    
    # Set the chart title
    ax.set_title(f"{phase.capitalize()} Metrics Radar Chart - Filter: {filter_keyword}", size=12, y=1.08)

    # Set the labels (performance metrics) around the radar axes
    ax.set_xticks(angles[:-1])              # Exclude the duplicate angle used to close the loop
    ax.set_xticklabels(labels)             # Metric names as axis labels

    # Set the radial axis (performance metric values)
    ax.set_yticks(set_yticks)               # Radial ticks (grid lines)
    ax.set_ylim(set_ylim[0], set_ylim[1])  # Y-axis range

    # Enable grid for readability
    ax.grid(True)

    # Add legend to identify each model, outside the chart
    ax.legend(loc='center left', bbox_to_anchor=(0.9, 0.9), fontsize=8)

    # Automatically adjust layout to avoid clipping
    plt.tight_layout()

    # Show the radar chart
    plt.show()

    # Return the name of the model with the highest accuracy
    return best_model

# %%
filter_keyword = "conv"
set_ylim=[0.6, 1.0]
set_yticks=[0.6, 0.7, 0.8, 0.9, 1.0]
fig_size = (5,5)


for phase in phases:
    if phase=='test':
        best_model_names.append(plot_radar_filtered(models_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size))
    else:
        plot_radar_filtered(models_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size)

# %%
filter_keyword = "DenseNet"
set_ylim=[0.6, 0.9]
set_yticks=[0.6, 0.7, 0.8, 0.9]
fig_size = (5,5)


for phase in phases:
    if phase=='test':
        best_model_names.append(plot_radar_filtered(models_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size))
    else:
        plot_radar_filtered(models_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size)

# %%
filter_keyword = "EfficientNet"
set_ylim=[0.6, 0.9]
set_yticks=[0.6, 0.7, 0.8, 0.9]
fig_size = (7,7)


for phase in phases:
    if phase=='test':
        best_model_names.append(plot_radar_filtered(models_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size))
    else:
        plot_radar_filtered(models_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size)

# %%
filter_keyword = ["Inception", "ResNet"]
set_ylim=[0.3, 0.9]
set_yticks=[0.4,0.5,0.6, 0.7, 0.8, 0.9]
fig_size = (5,5)


for phase in phases:
    if phase=='test':
        best_model_names.append(plot_radar_filtered(models_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size))
    else:
        plot_radar_filtered(models_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size)

# %%
filter_keyword = ["MobileNet", "NASNet"]
set_ylim=[0.3, 1.0]
set_yticks=[0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
fig_size = (5,5)


for phase in phases:
    if phase=='test':
        best_model_names.append(plot_radar_filtered(models_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size))
    else:
        plot_radar_filtered(models_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size)

# %%
filter_keyword = "VGG"
set_ylim=[0.6, 0.9]
set_yticks=[0.6, 0.7, 0.8, 0.9]
fig_size = (5,5)


for phase in phases:
    if phase=='test':
        best_model_names.append(plot_radar_filtered(models_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size))
    else:
        plot_radar_filtered(models_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size)

# %%
best_model_data = {model: models_data[model] for model in best_model_names if model in models_data}
print(best_model_data)
# Out:
# {'ConvNeXtXLarge': {'train': {'accuracy': 0.9325, 'precision': 0.9394, 'recall': 0.9325, 'f1_score': 0.9327}, 'validation': {'accuracy': 0.8808, 'precision': 0.8907, 'recall': 0.8808, 'f1_score': 0.8822}, 'test': {'accuracy': 0.8749, 'precision': 0.878, 'recall': 0.8749, 'f1_score': 0.8756}, 'param_count': 330000000, 'train_time_min': 280}, 'DenseNet201': {'train': {'accuracy': 0.8682, 'precision': 0.8895, 'recall': 0.8682, 'f1_score': 0.8672}, 'validation': {'accuracy': 0.8413, 'precision': 0.8685, 'recall': 0.8413, 'f1_score': 0.8426}, 'test': {'accuracy': 0.8296, 'precision': 0.8324, 'recall': 0.8296, 'f1_score': 0.8291}, 'param_count': 20000000, 'train_time_min': 150}, 'EfficientNetB2': {'train': {'accuracy': 0.8615, 'precision': 0.8757, 'recall': 0.8615, 'f1_score': 0.8601}, 'validation': {'accuracy': 0.8541, 'precision': 0.8904, 'recall': 0.8541, 'f1_score': 0.8551}, 'test': {'accuracy': 0.8549, 'precision': 0.8595, 'recall': 0.8549, 'f1_score': 0.8544}, 'param_count': 9200000,
# ...

# %%
filter_keyword = None
set_ylim=[0.6, 1.0]
set_yticks=[0.6, 0.7, 0.8, 0.9, 1.0]
fig_size = (6,6)


for phase in phases:
    if phase=='test':
        best_model_names.append(plot_radar_filtered(best_model_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size))
    else:
        plot_radar_filtered(best_model_data, phase, filter_keyword, set_ylim=set_ylim, set_yticks=set_yticks, fig_size = fig_size)

# %%
import pickle

# Save the full models_data dictionary
with open('models_data.pkl', 'wb') as f:
    pickle.dump(models_data, f)

# Save the best_model_data dictionary
with open('best_model_data.pkl', 'wb') as f:
    pickle.dump(best_model_data, f)

# %%
import pickle

# Load the full models_data dictionary
with open('models_data.pkl', 'rb') as f:
    models_data = pickle.load(f)

# Load the best_model_data dictionary
with open('best_model_data.pkl', 'rb') as f:
    best_model_data = pickle.load(f)
